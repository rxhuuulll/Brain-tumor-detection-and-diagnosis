# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import os

path = os.listdir("/content/drive/MyDrive/Projecttt/Training")
classes = {'no_tumor':0, 'pituitary_tumor':1}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = '/content/drive/MyDrive/Projecttt/Training/'+cls
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
X = np.array(X)
Y = np.array(Y)

X_updated = X.reshape(len(X), -1)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
pd.Series(Y).value_counts()
# Out:
# 1    857
# 0    395
# dtype: int64

# %%
X.shape, X_updated.shape
# Out:
# ((1252, 200, 200), (1252, 40000))

# %%
plt.imshow(X[0], cmap='gray')

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (1252, 40000)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10,test_size=.20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((1001, 40000), (251, 40000))

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
# pca_train = pca.fit_transform(xtrain)
# pca_test = pca.transform(xtest)
pca_train = xtrain
pca_test = xtest
# Out:
# (1001, 40000) (251, 40000)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

lg = LogisticRegression(C=0.1)
lg.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=0.1)

# %%
sv = SVC()
sv.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
print("Training Score:", lg.score(xtrain, ytrain))
print("Testing Score:", lg.score(xtest, ytest))
# Out:
# Training Score: 1.0
# Testing Score: 0.9681274900398407

# %%
pred = sv.predict(xtest)

# %%
misclassified=np.where(ytest!=pred)
misclassified
# Out:
# (array([  5,  32,  55,  66,  94,  95, 139, 166, 173, 195, 208, 214, 237]),)

# %%
print("Total Misclassified Samples: ",len(misclassified[0]))
print(pred[36],ytest[36])
# Out:
# Total Misclassified Samples:  13
# 1 1

# %%
dec = {0:'No Tumor', 1:'Positive Tumor'}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('/content/drive/MyDrive/Projecttt/Testing')
c=1
for i in os.listdir('/content/drive/MyDrive/Projecttt/Testing/no_tumor/')[:9]:
    plt.subplot(3,3,c)

    img = cv2.imread('/content/drive/MyDrive/Projecttt/Testing/no_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
import random

dec = {0: 'No Tumor', 1: 'Positive Tumor'}
med = {0: 'no medications', 1: random.choice(['    Radiation therapy', 'Transcranial surgery','     ETT surgery'])}

# %%
plt.figure(figsize=(12, 8))
p = os.listdir('/content/drive/MyDrive/Projecttt/Testing')
c = 1



title_top_positions = [(0.5, 1)] * 16
title_bottom_positions = [(180, -0.15)] * 16

for i in os.listdir('/content/drive/MyDrive/Projecttt/Testing/pituitary_tumor/')[:16]:
    plt.subplot(4, 4, c)

    img = cv2.imread('/content/drive/MyDrive/Projecttt/Testing/pituitary_tumor/' + i, 0)
    img1 = cv2.resize(img, (200, 200))
    img1 = img1.reshape(1, -1) / 255
    p = sv.predict(img1)

    plt.title(dec[p[0]], x=title_top_positions[c - 1][0], y=title_top_positions[c - 1][1], horizontalalignment='center')


    plt.imshow(img, cmap='gray')
    plt.axis('off')

    plt.text(title_bottom_positions[c - 1][0], title_bottom_positions[c - 1][1], med[p[0]], color='red', fontsize=9, horizontalalignment='center')

    c += 1

plt.show()

# %%
import random

dec1 = {0: 'No Tumor', 1: 'Positive Tumor'}
med1 = {0: 'no medications', 1: random.choice(['    Radiation therapy', '    Chemotherapy'])}

# %%
plt.figure(figsize=(12, 8))
p = os.listdir('/content/drive/MyDrive/Projecttt/Testing')
c = 1



title_top_positions = [(0.5, 1)] * 16
title_bottom_positions = [(180, -0.15)] * 16

for i in os.listdir('/content/drive/MyDrive/Projecttt/Testing/glioma_tumor/')[:16]:
    plt.subplot(4, 4, c)

    img = cv2.imread('/content/drive/MyDrive/Projecttt/Testing/glioma_tumor/' + i, 0)
    img1 = cv2.resize(img, (200, 200))
    img1 = img1.reshape(1, -1) / 255
    p = sv.predict(img1)

    plt.title(dec1[p[0]], x=title_top_positions[c - 1][0], y=title_top_positions[c - 1][1], horizontalalignment='center')


    plt.imshow(img, cmap='gray')
    plt.axis('off')

    plt.text(title_bottom_positions[c - 1][0], title_bottom_positions[c - 1][1], med1[p[0]], color='red', fontsize=9, horizontalalignment='center')

    c += 1

plt.show()

# %%
import random

dec2 = {0: 'No Tumor', 1: 'Positive Tumor'}
med2 = {0: 'no medications', 1: random.choice(['    Radiation therapy', '    Drugs'])}

# %%
plt.figure(figsize=(12, 8))
p = os.listdir('/content/drive/MyDrive/Projecttt/Testing')
c = 1



title_top_positions = [(0.5, 1)] * 16
title_bottom_positions = [(180, -0.15)] * 16

for i in os.listdir('/content/drive/MyDrive/Projecttt/Testing/meningioma_tumor/')[:16]:
    plt.subplot(4, 4, c)

    img = cv2.imread('/content/drive/MyDrive/Projecttt/Testing/meningioma_tumor/' + i, 0)
    img1 = cv2.resize(img, (200, 200))
    img1 = img1.reshape(1, -1) / 255
    p = sv.predict(img1)

    plt.title(dec2[p[0]], x=title_top_positions[c - 1][0], y=title_top_positions[c - 1][1], horizontalalignment='center')


    plt.imshow(img, cmap='gray')
    plt.axis('off')

    plt.text(title_bottom_positions[c - 1][0], title_bottom_positions[c - 1][1], med2[p[0]], color='red', fontsize=9, horizontalalignment='center')

    c += 1

plt.show()
